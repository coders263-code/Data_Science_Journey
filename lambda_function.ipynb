# %% [markdown]
# # ***Lecture 8***
# ## ***lambda functions***
# ### ***link of thius lecture https://drive.google.com/file/d/1KKSd979dt25ojXgKvE8I6mycQkTnZ_IV/view***

# %% [markdown]
# #### ***syntex***
#          a=lambda n,p :n**p
#          a(3,2)
#          Lambda is a key word
#
#         it is Also called Annonymous,one line and lambda function
#         In which,No Function name is declared
#         We call lambda function by creating object/variable

# %%
# Example
a=lambda n,p :n**p

a(3,2)
# Out:
# 9

# %% [markdown]
# ##### ***Celcius To Fahren..***

# %%
c_to_f= lambda c: (9/5)*c +32

c_to_f(45)
# Out:
# 113.0

# %% [markdown]
# ##### ***Finding Max***

# %%
find_max= lambda x,y: x if x>y else y 
find_max(3,5)
# Out:
# 5

# %% [markdown]
# #### ***Find length of a string***

# %%
a = lambda s: len(s)
a("saadi")
# Out:
# 5
