# %% [markdown]
# # ***Lecture 17***
# #### ***Read and write files in different Way***
# ##### ***link https://drive.google.com/file/d/1U1DONqccaUMEGRUaDnEOJWCOtMEIwLXc/view***

# %% [markdown]
# #### ***Data into json files***

# %%
data={
    "name":"saadi",
    "P.No":923280937263,
    "gmail":"Imsaadi7301@gmail.com"
}

# %%
import json

# %%
# Write mood
with open("data.json","w") as f:
    json.dump(data ,f)

# %%
# read mood
with open("data.json","r") as f:
    data1=json.load(f)
print(data1)
# Out:
# {'name': 'saadi', 'P.No': 923280937263, 'gmail': 'Imsaadi7301@gmail.com'}

# %% [markdown]
# #### ***File Operation into csv files***

# %%
# Write data into csv
import _csv
data3=[
    ["Name","PhonecNumber","Email"],
    ["saadi",923280937269,"imsaadi7301@gmail.com"],
    ["Afzal",923637664737,"afzal333333@gmail.com"]

]

# %%
with open("data3.csv" , "w") as f:
    writer=_csv.writer(f)
    for i in data3:
        writer.writerow(i)
