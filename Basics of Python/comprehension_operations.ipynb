# %% [markdown]
# # ***Lecture 7***
# ## ***Comprehensions***
# ### ***Link of this lecture is https://drive.google.com/file/d/1Ll_gCi7TUwhXY4H7qvR08Hi-a5Ge55j4/view ***

# %% [markdown]
# ### ***its working same like a loops***

# %%
#Example
# Convert list all items into upper case letters by usnig comprehension 
l=["saadi","asma","Fatima","Umer"]
[i.upper() for i in l]
# Out:
# ['SAADI', 'ASMA', 'FATIMA', 'UMER']
