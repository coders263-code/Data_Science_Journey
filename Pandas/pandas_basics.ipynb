# %% [markdown]
# # ***Lecture 1***
# ### ***Pandas Basics***
# ##### ***Link https://drive.google.com/file/d/1MRkzrhwETLHD3cnYDe4j9xCxHQtqou83/view***

# %%
import pandas as pd
import openpyxl

# %%
df=pd.read_excel("AI && ML.xlsx")
df
# Out:
#     S. No.            Main Topic  \
# 0        1  Python Basics (Live)
# 1        2            Data Types
# 2        3       Data Structures
# 3        4    Control Flow/Loops
# 4        5      Looping Practice
# ..     ...                   ...
# 218    216               Project
# 219    217               Project
# 220    218          Cloud Deploy
# 221    219          Cloud Deploy
# 222    220            Final Step
#
#              Lecture Name (Is order mein shuru karein)  Attendance  \
# 0    000. 30th Jan Live Class python basics (Aapka ...         NaN
# 1         000. 31st Jan Live Class list, tuple and set         NaN
# 2                                            005. Sets         NaN
# 3    000. 1st_Feb_Live_Class_dict_, conditional, _loop         NaN
# 4                               000. For Loop Practice         NaN
# ..                                                 ...         ...
# 218                005. Data Transformation ML Project         NaN
# ...

# %%
# Print first any values
df.head()
# Out:
#   S. No.            Main Topic  \
# 0      1  Python Basics (Live)
# 1      2            Data Types
# 2      3       Data Structures
# 3      4    Control Flow/Loops
# 4      5      Looping Practice
#
#            Lecture Name (Is order mein shuru karein)  Attendance  \
# 0  000. 30th Jan Live Class python basics (Aapka ...         NaN
# 1       000. 31st Jan Live Class list, tuple and set         NaN
# 2                                          005. Sets         NaN
# 3  000. 1st_Feb_Live_Class_dict_, conditional, _loop         NaN
# 4                             000. For Loop Practice         NaN
#
#                                           Unnamed: 4
# 0  https://drive.google.com/file/d/1D4yYXOlmD5TTm...
# 1  https://drive.google.com/file/d/1qHBqcMJGGpCNq...
# 2  https://drive.google.com/file/d/1QJeYi6cse7OYS...
# 3  https://drive.google.com/file/d/1c_llAE9Kk-O-f...
# 4  https://drive.google.com/file/d/1cFg4xiV_E-VSo...

# %%
# Print last values
df.tail()
# Out:
#     S. No.    Main Topic          Lecture Name (Is order mein shuru karein)  \
# 218    216       Project                005. Data Transformation ML Project
# 219    217       Project          003. End To End Project Decision Tree SVC
# 220    218  Cloud Deploy                           001. Deployment in Azure
# 221    219  Cloud Deploy         002. Deployment On Web Portal On AWS Cloud
# 222    220    Final Step  007. End To End Project Deployment (Project ko...
#
#      Attendance                                         Unnamed: 4
# 218         NaN  https://drive.google.com/file/d/1lRrGna5TJ_1wV...
# 219         NaN  https://drive.google.com/file/d/1NJ278hhlnKyRe...
# 220         NaN  https://drive.google.com/file/d/1_NecYJBnRDbGI...
# 221         NaN  https://drive.google.com/file/d/1ObFlsAu-QU8_u...
# 222         NaN  https://drive.google.com/file/d/1MUPtTaAvy0RT5...

# %%
# Check type of data
type(df)
# Out:
# pandas.DataFrame

# %%
# Save file into any format
df.to_csv("Pandas.csv")

# %%
# Print All columns
df.columns
# Out:
# Index(['S. No.', 'Main Topic', 'Lecture Name (Is order mein shuru karein)',
#        'Attendance', 'Unnamed: 4'],
#       dtype='str')

# %%
df[['S. No.', 'Main Topic']]
# Out:
#     S. No.            Main Topic
# 0        1  Python Basics (Live)
# 1        2            Data Types
# 2        3       Data Structures
# 3        4    Control Flow/Loops
# 4        5      Looping Practice
# ..     ...                   ...
# 218    216               Project
# 219    217               Project
# 220    218          Cloud Deploy
# 221    219          Cloud Deploy
# 222    220            Final Step
#
# [223 rows x 2 columns]
