# %% [markdown]
# # ***Lecture 18***
# ### ***Buffered_Read_And_Write_&_Other_File_Methods***
# #### ***Link https://drive.google.com/file/d/16O5oDA6cqIACOJTL1a1Zgr6mMep5CnJg/view***

# %%
# Examples
import io

# %%
with open("Text.txt","wb") as f:
    file= io.BufferedWriter(f)
    file.write(b"NMy name is Muhammad saadi")
    file.flush()
# flush() is used just like .close to closing file
